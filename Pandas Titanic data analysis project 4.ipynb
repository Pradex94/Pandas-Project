# %%
import pandas as pd
import json

# %%
import numpy as np
# pip show seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'c:\\Users\\HP\\AppData\\Local\\Programs\\Microsoft VS Code'

# %%
result=pd.read_json('https://raw.githubusercontent.com/jdorfman/awesome-json-datasets/refs/heads/master/package.json')

# %%
result[['scripts','repository']]
# result.columns
# Out:
#                                     scripts  \
# test          node tests/whitespace_test.js
# type                                    NaN
# url                                     NaN
# markdownlint                            NaN
#
#                                                      repository
# test                                                        NaN
# type                                                        git
# url           https://github.com/jdorfman/Awesome-JSON-Datasets
# markdownlint                                                NaN

# %%
pd.DataFrame(result)
# Out:
#                                     scripts  \
# test          node tests/whitespace_test.js
# type                                    NaN
# url                                     NaN
# markdownlint                            NaN
#
#                                                      repository  license  \
# test                                                        NaN  CC0 1.0
# type                                                        git  CC0 1.0
# url           https://github.com/jdorfman/Awesome-JSON-Datasets  CC0 1.0
# markdownlint                                                NaN  CC0 1.0
#
#              dependencies
# test                  NaN
# type                  NaN
# url                   NaN
# markdownlint       ^0.6.1

# %%
t="""result"""

# %%
import requests

url = 'https://raw.githubusercontent.com/jdorfman/awesome-json-datasets/refs/heads/master/package.json'
response = requests.get(url)

# Print the content of the response to inspect
print(response.text)
# Out:
# {
#   "scripts": {
#     "test": "node tests/whitespace_test.js"
#   },
#   "repository": {
#     "type": "git",
#     "url": "https://github.com/jdorfman/Awesome-JSON-Datasets"
#   },
#   "license": "CC0 1.0",
#   "dependencies": {
#     "markdownlint": "^0.6.1"
#   }
# }

# %%
import json

# %%
cd E:\Download1
# Out:
# E:\Download1

# %%
import requests

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59916',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59916/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59916/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59916/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/59916',
#   'id': 2554474168,
#   'node_id': 'PR_kwDOAA0YD859AOU-',
#   'number': 59916,
#   'title': 'ENH: Be able to add lines for all index levels, not just visible ones [fix #59877]',
#   'user': {'login': 'edbennett',
#    'id': 1698405,
#    'node_id': 'MDQ6VXNlcjE2OTg0MDU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1698405?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/edbennett',
#    'html_url': 'https://github.com/edbennett',
# ...

# %%
for i in range(len(data1)):
    if i=='1884158':
        print(data1[i]['user']['id'])
# data1[0]['user']['id']

# %%
d1=pd.DataFrame(data1)

# %%
d2=d1[['id','url','repository_url','labels_url','user']]

# %%
for b in range(len(d2)):
    # print(d2['user'][i]['login'])    
    d2['LOGIn_id1']=(d2['user'][b]['login'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16492\2589527029.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2['LOGIn_id1']=(d2['user'][b]['login'])

# %%
# len(d2)
d2['user'][2]['login']
# Out:
# 'saldanhad'

# %%
d2.pop('login_id')
# Out:
# 0     edbennett
# 1     edbennett
# 2     edbennett
# 3     edbennett
# 4     edbennett
# 5     edbennett
# 6     edbennett
# 7     edbennett
# 8     edbennett
# 9     edbennett
# 10    edbennett
# 11    edbennett
# 12    edbennett
# 13    edbennett
# 14    edbennett
# 15    edbennett
# 16    edbennett
# 17    edbennett
# 18    edbennett
# 19    edbennett
# 20    edbennett
# 21    edbennett
# 22    edbennett
# 23    edbennett
# 24    edbennett
# 25    edbennett
# 26    edbennett
# 27    edbennett
# 28    edbennett
# 29    edbennett
# Name: login_id, dtype: object

# %%
list1=[]
for i in range(len(d2)):
    # print(d2['user'][i]['login'])    
    login_id=d2['user'][i]['login']
    list1.append(login_id)
    # d2['login_id']=login
print(list1)
d2['login_id']=list1
# Out:
# ['edbennett', 'Zhdanovich', 'saldanhad', 'janezd', 'FuzzyParrabellum', 'jorisvandenbossche', 'Amir-101', 'shobsi', 'yuanx749', 'cdce8p', 'cdce8p', 'mhabets', 'robert-nash', 'KevsterAmp', 'KevsterAmp', 'noahblakesmith', 'simonaubertbd', 'jbrockmendel', 'Dr-Irv', 'jyotirjoshi', 'dbalabka', 'user-jx', 'SteffenR1098', 'niklassemmler', 'WillAyd', 'ArunPesari2', 'kuraga', 'jorisvandenbossche', 'saldanhad', 'edbennett']
# C:\Users\HP\AppData\Local\Temp\ipykernel_16492\813518475.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2['login_id']=list1

# %%
d2
# Out:
#             id                                                url  \
# 0   2554474168  https://api.github.com/repos/pandas-dev/pandas...
# 1   2554363630  https://api.github.com/repos/pandas-dev/pandas...
# 2   2554282457  https://api.github.com/repos/pandas-dev/pandas...
# 3   2554241969  https://api.github.com/repos/pandas-dev/pandas...
# 4   2552849510  https://api.github.com/repos/pandas-dev/pandas...
# 5   2552802383  https://api.github.com/repos/pandas-dev/pandas...
# 6   2552748177  https://api.github.com/repos/pandas-dev/pandas...
# 7   2552482698  https://api.github.com/repos/pandas-dev/pandas...
# 8   2552381459  https://api.github.com/repos/pandas-dev/pandas...
# 9   2551814732  https://api.github.com/repos/pandas-dev/pandas...
# 10  2551811130  https://api.github.com/repos/pandas-dev/pandas...
# 11  2550581040  https://api.github.com/repos/pandas-dev/pandas...
# 12  2550422790  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
d3=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')

# %%
d3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
d3.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
d3.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
d3.dtypes[d3.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
d3[d3.dtypes[d3.dtypes=='object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
d3.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
d3[d3['Age'].isnull()==True].index
# Out:
# Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#        ...
#        832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#       dtype='int64', length=177)

# %%
ind=d3[d3['Age'].isnull()==True].index

# %%
d3.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# # person who have paid highest fair

# %%
d3[d3['Fare']==d3['Fare'].max()]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %% [markdown]
# # how many male and female passanger onboarded

# %%
d3['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
d3.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %% [markdown]
# # how many servival we have

# %%
# d3[d3['Survived']==1].value_counts()
d3['Survived'].sum()
# Out:
# 342

# %% [markdown]
# # how many casuality we have

# %%
# d3[d3['Survived']==0].value_counts
d3['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
len(d3[d3['Survived']==0])
# Out:
# 549

# %% [markdown]
# # how many person we have age 60+

# %%
len(d3[d3['Age']>60])
# Out:
# 22

# %% [markdown]
# # name of the person eldest one

# %%
d3[d3['Age']==d3['Age'].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %% [markdown]
# # how many pessanger do we have in first , second and third class

# %%
d3['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
d3.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %% [markdown]
# # how many passanger whose name start with s

# %%
d3.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
len(d3[d3['Name'].str.endswith("S")]['Name'])
# Out:
# 0

# %% [markdown]
# # try to create a new column with summation of SibSp and Parch

# %%
d3.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
d3['new']=d3['SibSp']+d3['Parch']

# %% [markdown]
# # how many person do we have for age below 25

# %%
len(d3[d3['Age']<25])
# Out:
# 278

# %% [markdown]
# # how many person who died whose age was less than 40

# %%
len(d3[(d3['Survived']==0) & (d3['Age']<40)])
# Out:
# 322

# %% [markdown]
# # from cabin column seperate text and numeric value

# %%
d3.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new'],
#       dtype='object')

# %%
import re
d3['cabin_letters']=d3['Cabin'].str.extract('([A-Za-z]+)')
d3['cabin_numbers']=d3['Cabin'].str.replace("([A-Za-z]+)","q")

# %%
d3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
